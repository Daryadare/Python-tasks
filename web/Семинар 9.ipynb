# %% [markdown]
# # Семинар 9

# %% [markdown]
# На этом семинаре мы будем работать с известной [базой данных](http://campus.lakeforest.edu/frank/FILES/MLFfiles/Bio150/Titanic/TitanicMETA.pdf) по пассажирам "Титаника" (она часто используется в курсах по эконометрике и машинному обучению, но представляет не только статистической, но и содержательный интерес).
#
# *Переменные:*
#
# **PassengerId**  - id пассажира
#
# **Survived** - бинарный показатель, выжил пассажир или нет (1 - выжил, 0 - не выжил)
#
# **Pclass** - класс пассажира
#
# **Name** - имя пассажира
#
# **Sex**	- пол пассажира
#
# **Age**	- возраст пассажира
#
# **SibSp** - число родных братьев/сестер пассажира на борту корабля (или супругов)
#
# **Parch** - число родителей пассажира на борту корабля
#
# **Ticket**	- номер билета
#
# **Fare** - стоимость билета
#
# **Cabin** - каюта
#
# **Embarked** - порт, в котором пассажир взошел на палубу корабля

# %% [markdown]
# ### Загрузка и предварительная обработка

# %% [markdown]
# 1. Загрузите базу данных из файла `Titanic.csv`.
# 2. Загрузите базу данных так из файла еще раз, но так, чтобы столбец PassengerId был идентификатором, то есть номером  строки (*index)*.
# 3. Удалите из базы строки с пропущенными значениями и сохраните изменения в самой базе.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic_df_temp = pd.read_csv('C:/Users/User/Desktop/dtml/titanic.csv')
titanic_df_temp
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic_df = pd.read_csv('C:/Users/User/Desktop/dtml/titanic.csv',index_col=0)
titanic_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
titanic_df = titanic_df.dropna()
titanic_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 873                                   Carlsson, Mr. Frans Olof    male  33.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
#
#              SibSp  Parch    Ticket     Fare        Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833          C85        C
# 4                1      0    113803  53.1000         C123        S
# 7                0      0     17463  51.8625          E46        S
# 11               1      1   PP 9549  16.7000           G6        S
# 12               0      0    113783  26.5500         C103        S
# ...            ...    ...       ...      ...          ...      ...
# 872              1      1     11751  52.5542          D35        S
# 873              0      0       695   5.0000  B51 B53 B55        S
# 880              0      1     11767  83.1583          C50        C
# 888              0      0    112053  30.0000          B42        S
# 890              0      0    111369  30.0000         C148        C
#
# [183 rows x 11 columns]

# %% [markdown]
# ### Описание базы данных

# %% [markdown]
# 3. Выведите сводную информацию по базе данных: какие переменные в ней есть, какого они типа + сколько заполненных наблюдений в каждой столбце.
# 4. Выведите сводную статистическую информацию по каждому количественному показателю в базе (описательные статистике).
# 6. Постройте гистограмму для переменной *Возраст* (*Age*), сделайте ее красного цвета, подпишите оси и добавьте заголовок графика.
# 7. Выведите описательные статистики для столбца *Стоимость билета* (*Fare*).

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 2 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  183 non-null    int64
#  1   Pclass    183 non-null    int64
#  2   Name      183 non-null    object
#  3   Sex       183 non-null    object
#  4   Age       183 non-null    float64
#  5   SibSp     183 non-null    int64
#  6   Parch     183 non-null    int64
#  7   Ticket    183 non-null    object
#  8   Fare      183 non-null    float64
#  9   Cabin     183 non-null    object
#  10  Embarked  183 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 17.2+ KB

# %%
titanic_df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  183.000000  183.000000  183.000000  183.000000  183.000000  183.000000
# mean     0.672131    1.191257   35.674426    0.464481    0.475410   78.682469
# std      0.470725    0.515187   15.643866    0.644159    0.754617   76.347843
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%      1.000000    1.000000   47.500000    1.000000    1.000000   90.000000
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
plt.hist(titanic_df['Age'],color='red')
plt.title('Age histogram',size=14)
plt.xlabel('Age', size=12)
plt.ylabel('Quantity',size=12)
plt.grid(True)

# %%
titanic_df['Fare'].describe()
# Out:
# count    183.000000
# mean      78.682469
# std       76.347843
# min        0.000000
# 25%       29.700000
# 50%       57.000000
# 75%       90.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# ### Работа со строками и столбцами базы

# %% [markdown]
# 7. Выведите названия столбцов в базе данных в виде списка (объект типа *list*).
# 8. Переименуйте столбец с классом пассажира из **Pclass** в **Class**.
# 9. Выберите из базы данных все строки, которые соответствуют пассажирам женского пола, и сохраните их в новую базу `female`.
# 10. Выберите из базы данных все строки, которые соответствуют выжившим пассажирам мужского пола младше 32 лет, и сохраните их в базу `Ymale`.
# 11. Выберите из базы данных все строки, которые соответствуют пассажирам 1 или 2 класса.
# 12. Выберите из базы данных все строки, которые соответствуют выжившим пассажирам 1 или 2 класса.
# 12. Добавьте в датафрейм столбец *Female*, состоящий из значений 0 и 1, где 1 соответствует пассажирам женского пола.

# %%
col_list = list(titanic_df.columns)
col_list
# Out:
# ['Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
titanic_df=titanic_df.rename(columns={'Pclass':'Class'})
titanic_df
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 11                  1      3
# 12                  1      1
# ...               ...    ...
# 872                 1      1
# 873                 0      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 873                                   Carlsson, Mr. Frans Olof    male  33.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
#
#              SibSp  Parch    Ticket     Fare        Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833          C85        C
# 4                1      0    113803  53.1000         C123        S
# 7                0      0     17463  51.8625          E46        S
# 11               1      1   PP 9549  16.7000           G6        S
# 12               0      0    113783  26.5500         C103        S
# ...            ...    ...       ...      ...          ...      ...
# 872              1      1     11751  52.5542          D35        S
# 873              0      0       695   5.0000  B51 B53 B55        S
# 880              0      1     11767  83.1583          C50        C
# 888              0      0    112053  30.0000          B42        S
# 890              0      0    111369  30.0000         C148        C
#
# [183 rows x 11 columns]

# %%
female_df=titanic_df[titanic_df['Sex']=='female']
female_df
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 11                  1      3
# 12                  1      1
# 53                  1      1
# ...               ...    ...
# 854                 1      1
# 863                 1      1
# 872                 1      1
# 880                 1      1
# 888                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# ...                                                        ...     ...   ...
# 854                                  Lines, Miss. Mary Conover  female  16.0
# 863          Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 4                1      0    113803  53.1000  C123        S
# 11               1      1   PP 9549  16.7000    G6        S
# 12               0      0    113783  26.5500  C103        S
# 53               1      0  PC 17572  76.7292   D33        C
# ...            ...    ...       ...      ...   ...      ...
# 854              0      1  PC 17592  39.4000   D28        S
# 863              0      0     17466  25.9292   D17        S
# 872              1      1     11751  52.5542   D35        S
# 880              0      1     11767  83.1583   C50        C
# 888              0      0    112053  30.0000   B42        S
#
# [88 rows x 11 columns]

# %%
Ymale_df=titanic_df[(titanic_df['Sex']=='male') & (titanic_df['Age']<32)]
Ymale_df
# Out:
#              Survived  Class                                        Name  \
# PassengerId
# 24                  1      1                Sloper, Mr. William Thompson
# 28                  0      1              Fortune, Mr. Charles Alexander
# 76                  0      3                     Moen, Mr. Sigurd Hansen
# 98                  1      1             Greenfield, Mr. William Bertram
# 103                 0      1                   White, Mr. Richard Frasar
# 119                 0      1                    Baxter, Mr. Quigg Edmond
# 140                 0      1                          Giglio, Mr. Victor
# 184                 1      2                   Becker, Master. Richard F
# 194                 1      2                  Navratil, Master. Michel M
# 306                 1      1              Allison, Master. Hudson Trevor
# 337                 0      1                   Pears, Mr. Thomas Clinton
# 341                 1      2              Navratil, Master. Edmond Roger
# 371                 1      1                 Harder, Mr. George Achilles
# 378                 0      1                   Widener, Mr. Harry Elkins
# 431                 1      1   Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 446                 1      1                   Dodge, Master. Washington
# 453                 0      1             Foreman, Mr. Benjamin Laventall
# 485                 1      1                     Bishop, Mr. Dickinson H
# 506                 0      1  Penasco y Castellana, Mr. Victor de Satode
# 551                 1      1                 Thayer, Mr. John Borland Jr
# 672                 0      1                      Davidson, Mr. Thornton
# 682                 1      1                          Hassab, Mr. Hammad
# 691                 1      1                     Dick, Mr. Albert Adrian
# 716                 0      3  Soholt, Mr. Peter Andreas Lauritz Andersen
# 725                 1      1               Chambers, Mr. Norman Campbell
# 749                 0      1                   Marvin, Mr. Daniel Warner
# 752                 1      3                         Moor, Master. Meier
# 783                 0      1                      Long, Mr. Milton Clyde
# 803                 1      1         Carter, Master. William Thornton II
# 868                 0      1        Roebling, Mr. Washington Augustus II
# 890                 1      1                       Behr, Mr. Karl Howell
#
#               Sex    Age  SibSp  Parch      Ticket      Fare        Cabin  \
# PassengerId
# 24           male  28.00      0      0      113788   35.5000           A6
# 28           male  19.00      3      2       19950  263.0000  C23 C25 C27
# 76           male  25.00      0      0      348123    7.6500        F G73
# 98           male  23.00      0      1    PC 17759   63.3583      D10 D12
# 103          male  21.00      0      1       35281   77.2875          D26
# 119          male  24.00      0      1    PC 17558  247.5208      B58 B60
# 140          male  24.00      0      0    PC 17593   79.2000          B86
# 184          male   1.00      2      1      230136   39.0000           F4
# 194          male   3.00      1      1      230080   26.0000           F2
# 306          male   0.92      1      2      113781  151.5500      C22 C26
# 337          male  29.00      1      0      113776   66.6000           C2
# 341          male   2.00      1      1      230080   26.0000           F2
# 371          male  25.00      1      0       11765   55.4417          E50
# 378          male  27.00      0      2      113503  211.5000          C82
# 431          male  28.00      0      0      110564   26.5500          C52
# 446          male   4.00      0      2       33638   81.8583          A34
# 453          male  30.00      0      0      113051   27.7500         C111
# 485          male  25.00      1      0       11967   91.0792          B49
# 506          male  18.00      1      0    PC 17758  108.9000          C65
# 551          male  17.00      0      2       17421  110.8833          C70
# 672          male  31.00      1      0  F.C. 12750   52.0000          B71
# 682          male  27.00      0      0    PC 17572   76.7292          D49
# 691          male  31.00      1      0       17474   57.0000          B20
# 716          male  19.00      0      0      348124    7.6500        F G73
# 725          male  27.00      1      0      113806   53.1000           E8
# 749          male  19.00      1      0      113773   53.1000          D30
# 752          male   6.00      0      1      392096   12.4750         E121
# 783          male  29.00      0      0      113501   30.0000           D6
# 803          male  11.00      1      2      113760  120.0000      B96 B98
# 868          male  31.00      0      0    PC 17590   50.4958          A24
# 890          male  26.00      0      0      111369   30.0000         C148
#
#             Embarked
# PassengerId
# 24                 S
# 28                 S
# 76                 S
# 98                 C
# 103                S
# 119                C
# 140                C
# 184                S
# 194                S
# 306                S
# 337                S
# 341                S
# 371                C
# 378                C
# 431                S
# 446                S
# 453                C
# 485                C
# 506                C
# 551                C
# 672                S
# 682                C
# 691                S
# 716                S
# 725                S
# 749                S
# 752                S
# 783                S
# 803                S
# 868                S
# 890                C

# %%
fsclass_df=titanic_df[(titanic_df['Class']==1) | (titanic_df['Class']==2)]
fsclass_df
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 12                  1      1
# 22                  1      2
# ...               ...    ...
# 872                 1      1
# 873                 0      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 22                                       Beesley, Mr. Lawrence    male  34.0
# ...                                                        ...     ...   ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 873                                   Carlsson, Mr. Frans Olof    male  33.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
#
#              SibSp  Parch    Ticket     Fare        Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833          C85        C
# 4                1      0    113803  53.1000         C123        S
# 7                0      0     17463  51.8625          E46        S
# 12               0      0    113783  26.5500         C103        S
# 22               0      0    248698  13.0000          D56        S
# ...            ...    ...       ...      ...          ...      ...
# 872              1      1     11751  52.5542          D35        S
# 873              0      0       695   5.0000  B51 B53 B55        S
# 880              0      1     11767  83.1583          C50        C
# 888              0      0    112053  30.0000          B42        S
# 890              0      0    111369  30.0000         C148        C
#
# [173 rows x 11 columns]

# %%
aliveFSclass_df=titanic_df[((titanic_df['Class']==1) | (titanic_df['Class']==2)) & 
                           (titanic_df['Survived']==1)]
aliveFSclass_df
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 12                  1      1
# 22                  1      2
# 24                  1      1
# ...               ...    ...
# 863                 1      1
# 872                 1      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 22                                       Beesley, Mr. Lawrence    male  34.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# ...                                                        ...     ...   ...
# 863          Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 4                1      0    113803  53.1000  C123        S
# 12               0      0    113783  26.5500  C103        S
# 22               0      0    248698  13.0000   D56        S
# 24               0      0    113788  35.5000    A6        S
# ...            ...    ...       ...      ...   ...      ...
# 863              0      0     17466  25.9292   D17        S
# 872              1      1     11751  52.5542   D35        S
# 880              0      1     11767  83.1583   C50        C
# 888              0      0    112053  30.0000   B42        S
# 890              0      0    111369  30.0000  C148        C
#
# [118 rows x 11 columns]

# %%
gender=pd.get_dummies(titanic_df['Sex'])
gender
# Out:
#              female  male
# PassengerId
# 2                 1     0
# 4                 1     0
# 7                 0     1
# 11                1     0
# 12                1     0
# ...             ...   ...
# 872               1     0
# 873               0     1
# 880               1     0
# 888               1     0
# 890               0     1
#
# [183 rows x 2 columns]

# %%
titanic_df=pd.concat([titanic_df,gender['female']],axis=1)
titanic_df
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 11                  1      3
# 12                  1      1
# ...               ...    ...
# 872                 1      1
# 873                 0      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 873                                   Carlsson, Mr. Frans Olof    male  33.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
#
#              SibSp  Parch    Ticket     Fare        Cabin Embarked  female
# PassengerId
# 2                1      0  PC 17599  71.2833          C85        C       1
# 4                1      0    113803  53.1000         C123        S       1
# 7                0      0     17463  51.8625          E46        S       0
# 11               1      1   PP 9549  16.7000           G6        S       1
# 12               0      0    113783  26.5500         C103        S       1
# ...            ...    ...       ...      ...          ...      ...     ...
# 872              1      1     11751  52.5542          D35        S       1
# 873              0      0       695   5.0000  B51 B53 B55        S       0
# 880              0      1     11767  83.1583          C50        C       1
# 888              0      0    112053  30.0000          B42        S       1
# 890              0      0    111369  30.0000         C148        C       0
#
# [183 rows x 12 columns]

# %% [markdown]
# ### Группировка
# 1. Выведите на экран все уникальные значения в столбце *Embarked*.
# 2. Сгруппируйте строки в датафрейме в соответствии со значениями переменной *Survived* и выведите средние значения всех количественных переменных по группам.
# 3. Сгруппируйте строки в датафрейме в соответствии со значениями переменной *Sex* и сохраните в отдельный датафрейм таблицу со средними и медианными значениями переменной *Age* по группам (мужчины и женщины).

# %%
titanic_df['Embarked'].unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
titanic_df.groupby('Survived').agg('mean')
# Out:
#              Class        Age     SibSp     Parch       Fare    female
# Survived
# 0         1.216667  41.350000  0.366667  0.450000  64.048262  0.100000
# 1         1.178862  32.905854  0.512195  0.487805  85.821107  0.666667

# %%
titanic_df_sex=titanic_df.groupby('Sex').agg(['mean','median'])
titanic_df_sex
# Out:
#         Survived            Class               Age            SibSp         \
#             mean median      mean median       mean median      mean median
# Sex
# female  0.931818    1.0  1.215909    1.0  32.676136  32.25  0.534091    0.0
# male    0.431579    0.0  1.168421    1.0  38.451789  37.00  0.400000    0.0
#
#            Parch              Fare          female
#             mean median       mean   median   mean median
# Sex
# female  0.545455    0.0  89.000900  77.9583    1.0    1.0
# male    0.410526    0.0  69.124343  51.8625    0.0    0.0

# %% [markdown]
# ### Выгрузка базы в файл
# 1. Приведите все названия столбцов в датафрейме к нижнему регистру и сохраните изменения.
# 2. Выгрузите итоговый датафрейм в файл `Titanic-new.csv`.

# %%
titanic_df=titanic_df.rename(str.lower,axis=1)
titanic_df
# Out:
#              survived  class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 11                  1      3
# 12                  1      1
# ...               ...    ...
# 872                 1      1
# 873                 0      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           name     sex   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 873                                   Carlsson, Mr. Frans Olof    male  33.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
#
#              sibsp  parch    ticket     fare        cabin embarked  female
# PassengerId
# 2                1      0  PC 17599  71.2833          C85        C       1
# 4                1      0    113803  53.1000         C123        S       1
# 7                0      0     17463  51.8625          E46        S       0
# 11               1      1   PP 9549  16.7000           G6        S       1
# 12               0      0    113783  26.5500         C103        S       1
# ...            ...    ...       ...      ...          ...      ...     ...
# 872              1      1     11751  52.5542          D35        S       1
# 873              0      0       695   5.0000  B51 B53 B55        S       0
# 880              0      1     11767  83.1583          C50        C       1
# 888              0      0    112053  30.0000          B42        S       1
# 890              0      0    111369  30.0000         C148        C       0
#
# [183 rows x 12 columns]

# %%
titanic_df.to_csv('Titanic-new.csv')
